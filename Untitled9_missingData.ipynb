# %% [markdown]
# <a href="https://colab.research.google.com/github/Ovanjohn/basicPython/blob/main/Untitled9_missingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_excel('/content/missingData.xlsx')

df
# Out:
#           date     open     high      low    close
# 0   2023-01-23      NaN  1.09271  1.08464  1.08715
# 1   2023-01-24      NaN  1.08982  1.08352  1.08885
# 2   2023-01-25      NaN  1.09239  1.08573  1.09149
# 3   2023-01-26      NaN  1.09296  1.08508  1.08914
# 4   2023-01-27      NaN  1.09006  1.08379  1.08679
# ..         ...      ...      ...      ...      ...
# 125 2023-07-17  1.12302  1.12489  1.12037      NaN
# 126 2023-07-18  1.12370  1.12759  1.12091      NaN
# 127 2023-07-19  1.12281  1.12404  1.11746  1.12025
# 128 2023-07-20  1.12004  1.12292  1.11187  1.11298
# 129 2023-07-21  1.11324  1.11446  1.11094  1.11258
#
# [130 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    130 non-null    datetime64[ns]
#  1   open    119 non-null    float64
#  2   high    130 non-null    float64
#  3   low     114 non-null    float64
#  4   close   119 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 5.2 KB

# %%
df.head(100)
# Out:
#          date     open     high      low    close
# 0  2023-01-23      NaN  1.09271  1.08464  1.08715
# 1  2023-01-24      NaN  1.08982  1.08352  1.08885
# 2  2023-01-25      NaN  1.09239  1.08573  1.09149
# 3  2023-01-26      NaN  1.09296  1.08508  1.08914
# 4  2023-01-27      NaN  1.09006  1.08379  1.08679
# ..        ...      ...      ...      ...      ...
# 95 2023-06-05  1.07076  1.07226  1.06747  1.07127
# 96 2023-06-06  1.07148  1.07331  1.06672  1.06925
# 97 2023-06-07  1.06938  1.07398  1.06684  1.06991
# 98 2023-06-08  1.06977  1.07872  1.06966  1.07832
# 99 2023-06-09  1.07815  1.07856  1.07430  1.07499
#
# [100 rows x 5 columns]

# %%
#Removing rows with missing values
df.dropna()
# Out:
#           date     open     high      low    close
# 11  2023-02-07  1.07263  1.07668  1.06693  1.07278
# 12  2023-02-08  1.07241  1.07609  1.07096  1.07144
# 13  2023-02-09  1.07136  1.07910  1.07096  1.07388
# 14  2023-02-10  1.07369  1.07529  1.06665  1.06787
# 15  2023-02-13  1.06832  1.07300  1.06557  1.07252
# ..         ...      ...      ...      ...      ...
# 114 2023-06-30  1.08647  1.09320  1.08354  1.09111
# 115 2023-07-03  1.09117  1.09341  1.08704  1.09130
# 127 2023-07-19  1.12281  1.12404  1.11746  1.12025
# 128 2023-07-20  1.12004  1.12292  1.11187  1.11298
# 129 2023-07-21  1.11324  1.11446  1.11094  1.11258
#
# [92 rows x 5 columns]

# %%
#Removing columns with missing values
df.dropna(axis=1)
# Out:
#           date     high
# 0   2023-01-23  1.09271
# 1   2023-01-24  1.08982
# 2   2023-01-25  1.09239
# 3   2023-01-26  1.09296
# 4   2023-01-27  1.09006
# ..         ...      ...
# 125 2023-07-17  1.12489
# 126 2023-07-18  1.12759
# 127 2023-07-19  1.12404
# 128 2023-07-20  1.12292
# 129 2023-07-21  1.11446
#
# [130 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    130 non-null    datetime64[ns]
#  1   open    119 non-null    float64
#  2   high    130 non-null    float64
#  3   low     114 non-null    float64
#  4   close   119 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 5.2 KB

# %%
#Returns a dataFrame of the same shape with True for missing values
df.isnull()
# Out:
#       date   open   high    low  close
# 0    False   True  False  False  False
# 1    False   True  False  False  False
# 2    False   True  False  False  False
# 3    False   True  False  False  False
# 4    False   True  False  False  False
# ..     ...    ...    ...    ...    ...
# 125  False  False  False  False   True
# 126  False  False  False  False   True
# 127  False  False  False  False  False
# 128  False  False  False  False  False
# 129  False  False  False  False  False
#
# [130 rows x 5 columns]

# %%
#Returns a dataFrame of the same shape with True for non-missing values
df.notnull()
# Out:
#      date   open  high   low  close
# 0    True  False  True  True   True
# 1    True  False  True  True   True
# 2    True  False  True  True   True
# 3    True  False  True  True   True
# 4    True  False  True  True   True
# ..    ...    ...   ...   ...    ...
# 125  True   True  True  True  False
# 126  True   True  True  True  False
# 127  True   True  True  True   True
# 128  True   True  True  True   True
# 129  True   True  True  True   True
#
# [130 rows x 5 columns]

# %%
#Filling missing values with specified 'values'
df.fillna(1.07136)
# Out:
#           date     open     high      low    close
# 0   2023-01-23  1.07136  1.09271  1.08464  1.08715
# 1   2023-01-24  1.07136  1.08982  1.08352  1.08885
# 2   2023-01-25  1.07136  1.09239  1.08573  1.09149
# 3   2023-01-26  1.07136  1.09296  1.08508  1.08914
# 4   2023-01-27  1.07136  1.09006  1.08379  1.08679
# ..         ...      ...      ...      ...      ...
# 125 2023-07-17  1.12302  1.12489  1.12037  1.07136
# 126 2023-07-18  1.12370  1.12759  1.12091  1.07136
# 127 2023-07-19  1.12281  1.12404  1.11746  1.12025
# 128 2023-07-20  1.12004  1.12292  1.11187  1.11298
# 129 2023-07-21  1.11324  1.11446  1.11094  1.11258
#
# [130 rows x 5 columns]

# %%
#Filling missing values with the previous non-missing values
df.fillna(method='ffill')
# Out:
#           date     open     high      low    close
# 0   2023-01-23      NaN  1.09271  1.08464  1.08715
# 1   2023-01-24      NaN  1.08982  1.08352  1.08885
# 2   2023-01-25      NaN  1.09239  1.08573  1.09149
# 3   2023-01-26      NaN  1.09296  1.08508  1.08914
# 4   2023-01-27      NaN  1.09006  1.08379  1.08679
# ..         ...      ...      ...      ...      ...
# 125 2023-07-17  1.12302  1.12489  1.12037  1.09130
# 126 2023-07-18  1.12370  1.12759  1.12091  1.09130
# 127 2023-07-19  1.12281  1.12404  1.11746  1.12025
# 128 2023-07-20  1.12004  1.12292  1.11187  1.11298
# 129 2023-07-21  1.11324  1.11446  1.11094  1.11258
#
# [130 rows x 5 columns]

# %%
#Replace missing values with a calcuated value, such as the mean or median.
df['close'].fillna(df['high'].mean(1.09149), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     553         try:
# --> 554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
#
# KeyError: 1.09149
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-897a3ba8b005> in <cell line: 2>()
#       1 #Replace missing values with a calcuated value, such as the mean or median.
# ----> 2 df['close'].fillna(df['high'].mean(1.09149), inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# ...

# %%
df.describe

# %%
#Estimating missing values bassed on other values in the dataFrame
df.interpolate()

# %%
 #Selecting a single column
date_column = df['date']
date_column

# %%
 #Selecting a single column
open_column = df['open']
open_column

# %%
 #Selecting a single column
high_column = df['high']
high_column

# %%
 #Selecting a single column
low_column = df['low']
low_column

# %%
# Selecting a single column
close_column = df['close']
close_column

# %%
# Selecting multiple columns
subset = df[['open', 'close']]
subset

# %%
# Selecting multiple columns
subset = df[['high', 'low']]
subset

# %%
df.rename(columns = {"open" : "opening values"}, inplace=True)

df

# %%
df.rename(columns = {"close" : "closing values"}, inplace=True)
df

# %%
df.corr()

# %%
len(df)
